# %%
import pandas as pd

df = pd.read_csv('spotify.csv')

print(df)
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %%
print(df.head(3))
# Out:
#                     title        artist                  top genre  year  \
# 0         Blinding Lights    The Weeknd  canadian contemporary r&b  2020
# 1        Watermelon Sugar  Harry Styles                        pop  2019
# 2  Mood (feat. iann dior)      24kGoldn                   cali rap  2021
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
# 1                95      82            55           -4        34       56
# 2                91      72            70           -4        32       73
#
#    length  acousticness  speechiness  popularity
# 0     200             0            6          91
# 1     174            12            5          88
# 2     141            17            4          88

# %%
print(df.tail)
# Out:
# <bound method NDFrame.tail of                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %%
# df_xlsx=pd.read_excel('spotify.xlsx')
# df= pd.read_scv('spotify.txt', delimiter='XXX'or '\t')
# print(df)
#other types of documents

# %%
print(df.columns)#these are headers, columns
# Out:
# Index(['title', 'artist', 'top genre', 'year', 'beats.per.minute', 'energy',
#        'danceability', 'loudness.dB', 'liveness', 'valance', 'length',
#        'acousticness', 'speechiness', 'popularity'],
#       dtype='object')

# %%
print(df['year'][0:5])#these are top 5 in year column
# Out:
# 0    2020
# 1    2019
# 2    2021
# 3    2019
# 4    2017
# Name: year, dtype: int64

# %%
print(df.year)
# Out:
# 0     2020
# 1     2019
# 2     2021
# 3     2019
# 4     2017
#       ...
# 95    2016
# 96    2015
# 97    2021
# 98    2018
# 99    2016
# Name: year, Length: 100, dtype: int64

# %%
print(df[['year','artist','title']])#multiple columns
# Out:
#     year         artist                                title
# 0   2020     The Weeknd                      Blinding Lights
# 1   2019   Harry Styles                     Watermelon Sugar
# 2   2021       24kGoldn               Mood (feat. iann dior)
# 3   2019  Lewis Capaldi                    Someone You Loved
# 4   2017     Ed Sheeran                              Perfect
# ..   ...            ...                                  ...
# 95  2016          Drake                            One Dance
# 96  2015       Maroon 5                                Sugar
# 97  2021     Mark Mendy                             Emotions
# 98  2018    Major Lazer                           Cold Water
# 99  2016    Mike Posner  I Took A Pill In Ibiza - Seeb Remix
#
# [100 rows x 3 columns]

# %%
print(df.head(4))
# Out:
#                     title         artist                  top genre  year  \
# 0         Blinding Lights     The Weeknd  canadian contemporary r&b  2020
# 1        Watermelon Sugar   Harry Styles                        pop  2019
# 2  Mood (feat. iann dior)       24kGoldn                   cali rap  2021
# 3       Someone You Loved  Lewis Capaldi                        pop  2019
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
# 1                95      82            55           -4        34       56
# 2                91      72            70           -4        32       73
# 3               110      41            50           -6        11       45
#
#    length  acousticness  speechiness  popularity
# 0     200             0            6          91
# 1     174            12            5          88
# 2     141            17            4          88
# ...

# %%
print(df.iloc[1])
# Out:
# title               Watermelon Sugar
# artist                  Harry Styles
# top genre                        pop
# year                            2019
# beats.per.minute                  95
# energy                            82
# danceability                      55
# loudness.dB                       -4
# liveness                          34
# valance                           56
# length                           174
# acousticness                      12
# speechiness                        5
# popularity                        88
# Name: 1, dtype: object

# %%
print(df.iloc[1:3])
# Out:
#                     title        artist top genre  year  beats.per.minute  \
# 1        Watermelon Sugar  Harry Styles       pop  2019                95
# 2  Mood (feat. iann dior)      24kGoldn  cali rap  2021                91
#
#    energy  danceability  loudness.dB  liveness  valance  length  acousticness  \
# 1      82            55           -4        34       56     174            12
# 2      72            70           -4        32       73     141            17
#
#    speechiness  popularity
# 1            5          88
# 2            4          88

# %%
print(df.iloc[2,1])#read specific location
# Out:
# 24kGoldn

# %%
for index, row in df.iterrows():
    print(index,row['artist'])
# Out:
# 0 The Weeknd
# 1 Harry Styles
# 2 24kGoldn
# 3 Lewis Capaldi
# 4 Ed Sheeran
# 5 Imagine Dragons
# 6 Billie Eilish
# 7 Post Malone
# 8 Ed Sheeran
# 9 Maroon 5
# 10 The Chainsmokers
# 11 Billie Eilish
# 12 James Arthur
# 13 Juice WRLD
# 14 John Legend
# 15 Ariana Grande
# 16 XXXTENTACION
# 17 Travis Scott
# 18 Avicii
# 19 DaBaby
# 20 Post Malone
# 21 Ed Sheeran
# 22 XXXTENTACION
# 23 Travis Scott
# 24 Twenty One Pilots
# 25 SAINt JHN
# 26 Roddy Ricch
# 27 The Weeknd
# 28 Post Malone
# 29 Ed Sheeran
# 30 The Weeknd
# 31 Justin Bieber
# 32 The Chainsmokers
# 33 Lady Gaga
# 34 Imagine Dragons
# 35 Lil Uzi Vert
# 36 Hozier
# 37 Marshmello
# 38 Ariana Grande
# 39 OneRepublic
# 40 Macklemore & Ryan Lewis
# 41 Shawn Mendes
# 42 Drake
# 43 Dua Lipa
# 44 Queen
# 45 Kendrick Lamar
# 46 DJ Snake
# 47 Post Malone
# 48 Sam Smith
# 49 Shawn Mendes
# 50 Mark Ronson
# 51 Lauv
# 52 Billie Eilish
# 53 The Killers
# 54 Tones And I
# 55 Camila Cabello
# 56 Post Malone
# 57 Ed Sheeran
# 58 French Montana
# ...

# %%
 df.loc[df['top genre']=="pop"]
# Out:
#                                                title         artist top genre  \
# 1                                   Watermelon Sugar   Harry Styles       pop
# 3                                  Someone You Loved  Lewis Capaldi       pop
# 4                                            Perfect     Ed Sheeran       pop
# 8                                       Shape of You     Ed Sheeran       pop
# 9                                           Memories       Maroon 5       pop
# 12                              Say You Won't Let Go   James Arthur       pop
# 21                                        Photograph     Ed Sheeran       pop
# 29                                 Thinking out Loud     Ed Sheeran       pop
# 57                 I Don't Care (with Justin Bieber)     Ed Sheeran       pop
# 87  Girls Like You (feat. Cardi B) - Cardi B Version       Maroon 5       pop
# 96                                             Sugar       Maroon 5       pop
#
# ...

# %%
df.describe()
# Out:
#               year  beats.per.minute      energy  danceability  loudness.dB  \
# count   100.000000        100.000000  100.000000     100.00000   100.000000
# mean   2015.960000        116.970000   62.680000      66.96000    -6.100000
# std       5.327497         27.470629   16.491737      13.60401     1.987334
# min    1975.000000         71.000000   11.000000      35.00000   -14.000000
# 25%    2015.000000         95.000000   52.000000      59.00000    -7.000000
# 50%    2017.000000        115.000000   64.500000      69.00000    -6.000000
# 75%    2018.000000        135.250000   76.000000      77.00000    -5.000000
# max    2021.000000        186.000000   92.000000      91.00000    -3.000000
#
#          liveness     valance      length  acousticness  speechiness  \
# count  100.000000  100.000000  100.000000     100.00000   100.000000
# mean    16.860000   49.970000  214.530000      24.95000     9.930000
# std     12.972403   21.737857   35.934974      26.27876     9.424077
# ...

# %%
df
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %%
df.sort_values('top genre', ascending=False)
# Out:
#                                title                   artist  \
# 23                        SICKO MODE             Travis Scott
# 17                        goosebumps             Travis Scott
# 40  Can't Hold Us - feat. Ray Dalton  Macklemore & Ryan Lewis
# 97                          Emotions               Mark Mendy
# 1                   Watermelon Sugar             Harry Styles
# ..                               ...                      ...
# 82           Wonderwall - Remastered                    Oasis
# 54                      Dance Monkey              Tones And I
# 86                     Cheap Thrills                      Sia
# 53                    Mr. Brightside              The Killers
# 68                         I'm Yours               Jason Mraz
#
#            top genre  year  beats.per.minute  energy  danceability  \
# 23               rap  2018               155      73            83
# 17               rap  2016               130      73            84
# ...

# %%
df.sort_values(['top genre', 'title'], ascending=False)
# Out:
#                                title                   artist  \
# 17                        goosebumps             Travis Scott
# 23                        SICKO MODE             Travis Scott
# 40  Can't Hold Us - feat. Ray Dalton  Macklemore & Ryan Lewis
# 97                          Emotions               Mark Mendy
# 1                   Watermelon Sugar             Harry Styles
# ..                               ...                      ...
# 82           Wonderwall - Remastered                    Oasis
# 54                      Dance Monkey              Tones And I
# 86                     Cheap Thrills                      Sia
# 53                    Mr. Brightside              The Killers
# 68                         I'm Yours               Jason Mraz
#
#            top genre  year  beats.per.minute  energy  danceability  \
# 17               rap  2016               130      73            84
# 23               rap  2018               155      73            83
# ...

# %%
df.sort_values(['top genre', 'title'], ascending=[1,0])
# Out:
#                                                title                   artist  \
# 68                                         I'm Yours               Jason Mraz
# 53                                    Mr. Brightside              The Killers
# 86                                     Cheap Thrills                      Sia
# 54                                      Dance Monkey              Tones And I
# 82                           Wonderwall - Remastered                    Oasis
# ..                                               ...                      ...
# 87  Girls Like You (feat. Cardi B) - Cardi B Version                 Maroon 5
# 97                                          Emotions               Mark Mendy
# 40                  Can't Hold Us - feat. Ray Dalton  Macklemore & Ryan Lewis
# 17                                        goosebumps             Travis Scott
# 23                                        SICKO MODE             Travis Scott
#
# ...

# %%
df.head(5)
# Out:
#                     title         artist                  top genre  year  \
# 0         Blinding Lights     The Weeknd  canadian contemporary r&b  2020
# 1        Watermelon Sugar   Harry Styles                        pop  2019
# 2  Mood (feat. iann dior)       24kGoldn                   cali rap  2021
# 3       Someone You Loved  Lewis Capaldi                        pop  2019
# 4                 Perfect     Ed Sheeran                        pop  2017
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
# 1                95      82            55           -4        34       56
# 2                91      72            70           -4        32       73
# 3               110      41            50           -6        11       45
# 4                95      45            60           -6        11       17
#
#    length  acousticness  speechiness  popularity
# ...

# %%
df['total']=df['energy']+ df['danceability']
df.head(5)
# Out:
#                     title         artist                  top genre  year  \
# 0         Blinding Lights     The Weeknd  canadian contemporary r&b  2020
# 1        Watermelon Sugar   Harry Styles                        pop  2019
# 2  Mood (feat. iann dior)       24kGoldn                   cali rap  2021
# 3       Someone You Loved  Lewis Capaldi                        pop  2019
# 4                 Perfect     Ed Sheeran                        pop  2017
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
# 1                95      82            55           -4        34       56
# 2                91      72            70           -4        32       73
# 3               110      41            50           -6        11       45
# 4                95      45            60           -6        11       17
#
#    length  acousticness  speechiness  popularity  total
# ...

# %%
df['total']=df['energy']+ df['danceability']
df.head(5)
df.drop(columns=['total'])
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %%
df['total']=df.iloc[:,4:5].sum(axis=1)
df.head(5)#min20
# Out:
#                     title         artist                  top genre  year  \
# 0         Blinding Lights     The Weeknd  canadian contemporary r&b  2020
# 1        Watermelon Sugar   Harry Styles                        pop  2019
# 2  Mood (feat. iann dior)       24kGoldn                   cali rap  2021
# 3       Someone You Loved  Lewis Capaldi                        pop  2019
# 4                 Perfect     Ed Sheeran                        pop  2017
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
# 1                95      82            55           -4        34       56
# 2                91      72            70           -4        32       73
# 3               110      41            50           -6        11       45
# 4                95      45            60           -6        11       17
#
#    length  acousticness  speechiness  popularity  total
# ...

# %%
print(df)
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %%
cols = list(df.colmns.values)
df= df[cols[0:4]+[cols[-1]]+[4:12]]  #this is a string"" cols[-1] make it a list by surroundingit with brackets
df.head(5) #min28
# Out:
#   File "<ipython-input-35-a8afbd3cd013>", line 2
#     df= df[cols[0:4]+[cols[-1]]+[4:12]]  #this is a string"" cols[-1] make it a list by surroundingit with brackets
#                                   ^
# SyntaxError: invalid syntax

# %%
df.to_csv('modified.csv')#created a new file in the directory

# %%
df.to_csv('modified.csv', index=False)#remove index

# %%
# df.to_excel('modified.xlsx')
# df.to_excel('modified.txt', sep='\t')  other options

# %%
df.loc[(df['artist']=='') & (df['artist']=='')]

# %%
df.loc[(df['artist']=='') | (df['year']=='')] #or instead of and

# %%
df.loc[(df['artist']=='') & (df['year']> 2015)]

# %%
new_df=df.loc[(df['artist']=='') & (df['year']> 2015)]
new_df

# %%
df

# %%
new_df.to_csv('filtered.csv') #save to see the new filtered results in your new document

# %%
#to reset the results with new index, old indexes will be confusing as they are now out of order
new_df=new_df.reset_index()

# %%
new_df=new_df.reset_index(drop=True)#drop the old indexes
new_df

# %%
#or without setting it. to. a new variable
new_df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %%
df.loc[df['artist'].str.contains('The')]
# Out:
#                        title            artist                  top genre  \
# 0            Blinding Lights        The Weeknd  canadian contemporary r&b
# 10                    Closer  The Chainsmokers                  dance pop
# 27                 The Hills        The Weeknd  canadian contemporary r&b
# 30                   Starboy        The Weeknd  canadian contemporary r&b
# 32  Something Just Like This  The Chainsmokers                  dance pop
# 53            Mr. Brightside       The Killers           alternative rock
# 72         Don't Let Me Down  The Chainsmokers                  dance pop
# 77        Can't Feel My Face        The Weeknd  canadian contemporary r&b
#
#     year  beats.per.minute  energy  danceability  loudness.dB  liveness  \
# 0   2020               171      73            51           -6         9
# 10  2016                95      52            75           -6        11
# 27  2015               113      56            59           -7        14
# ...

# %%
df.loc[~df['artist'].str.contains('The')]
# Out:
#                                   title           artist         top genre  \
# 1                      Watermelon Sugar     Harry Styles               pop
# 2                Mood (feat. iann dior)         24kGoldn          cali rap
# 3                     Someone You Loved    Lewis Capaldi               pop
# 4                               Perfect       Ed Sheeran               pop
# 5                              Believer  Imagine Dragons       modern rock
# ..                                  ...              ...               ...
# 95                            One Dance            Drake  canadian hip hop
# 96                                Sugar         Maroon 5               pop
# 97                             Emotions       Mark Mendy         pop dance
# 98                           Cold Water      Major Lazer         dance pop
# 99  I Took A Pill In Ibiza - Seeb Remix      Mike Posner         dance pop
#
# ...

# %%
import re

df.loc[df['artist'].str.contains('The|Ed', regex=True)]
# Out:
#                                 title            artist  \
# 0                     Blinding Lights        The Weeknd
# 4                             Perfect        Ed Sheeran
# 8                        Shape of You        Ed Sheeran
# 10                             Closer  The Chainsmokers
# 21                         Photograph        Ed Sheeran
# 27                          The Hills        The Weeknd
# 29                  Thinking out Loud        Ed Sheeran
# 30                            Starboy        The Weeknd
# 32           Something Just Like This  The Chainsmokers
# 53                     Mr. Brightside       The Killers
# 57  I Don't Care (with Justin Bieber)        Ed Sheeran
# 72                  Don't Let Me Down  The Chainsmokers
# 77                 Can't Feel My Face        The Weeknd
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# ...

# %%
import re

df.loc[df['artist'].str.contains('the|ed',flags=re.I ,regex=True)]
# Out:
#                                 title            artist  \
# 0                     Blinding Lights        The Weeknd
# 4                             Perfect        Ed Sheeran
# 8                        Shape of You        Ed Sheeran
# 10                             Closer  The Chainsmokers
# 21                         Photograph        Ed Sheeran
# 27                          The Hills        The Weeknd
# 29                  Thinking out Loud        Ed Sheeran
# 30                            Starboy        The Weeknd
# 32           Something Just Like This  The Chainsmokers
# 53                     Mr. Brightside       The Killers
# 57  I Don't Care (with Justin Bieber)        Ed Sheeran
# 72                  Don't Let Me Down  The Chainsmokers
# 77                 Can't Feel My Face        The Weeknd
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# ...

# %%
import re
#include po

df.loc[df['top genre'].str.contains('po[a-z]*', regex=True)]
# Out:
#                                                 title  \
# 0                                     Blinding Lights
# 1                                    Watermelon Sugar
# 3                                   Someone You Loved
# 4                                             Perfect
# 6                                lovely (with Khalid)
# 8                                        Shape of You
# 9                                            Memories
# 10                                             Closer
# 11                                            bad guy
# 12                               Say You Won't Let Go
# 15                                            7 rings
# 18                                         Wake Me Up
# 21                                         Photograph
# 27                                          The Hills
# 29                                  Thinking out Loud
# 30                                            Starboy
# ...

# %%
import re
#begin w/ po

df.loc[df['top genre'].str.contains('^po[a-z]*', regex=True)]
# Out:
#                                                title                   artist  \
# 1                                   Watermelon Sugar             Harry Styles
# 3                                  Someone You Loved            Lewis Capaldi
# 4                                            Perfect               Ed Sheeran
# 8                                       Shape of You               Ed Sheeran
# 9                                           Memories                 Maroon 5
# 12                              Say You Won't Let Go             James Arthur
# 21                                        Photograph               Ed Sheeran
# 29                                 Thinking out Loud               Ed Sheeran
# 40                  Can't Hold Us - feat. Ray Dalton  Macklemore & Ryan Lewis
# 57                 I Don't Care (with Justin Bieber)               Ed Sheeran
# 87  Girls Like You (feat. Cardi B) - Cardi B Version                 Maroon 5
# ...

# %%
df.loc[df['top genre']=='pop dance','top genre']='pop'

# %%
df
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %%
#changed a label under a column

# %%
df.loc[df['top genre']=='pop dance','best genre']='pop'

# %%
df
#now #99. should be showing true in the last. column. all. the way to. the right
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %%
df= pd.read_csv('modified.csv') #reverts back to before the previous changesdirectly above.

# %%
df
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %%
df.loc[df['total']>50,['danceability','energy']]='TEST Value'
df

#if total. is >50 the next two columns should say 'TEST Value' instead of the original value
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute      energy  \
# 0   canadian contemporary r&b  2020               171  TEST Value
# 1                         pop  2019                95  TEST Value
# 2                    cali rap  2021                91  TEST Value
# ...

# %%
#These are Conditional Changes btw - min46 for addt'l example

# %%
#switching to AGGREGATE Stats (Groupby)

# %%
df = pd.read_csv('modified.csv')
df.groupby(['title']).mean().sort_values('energy', ascending=False)
# Out:
#                                   year  beats.per.minute  energy  \
# title
# Can't Hold Us - feat. Ray Dalton  2012               146      92
# Mr. Brightside                    2004               148      91
# Wonderwall - Remastered           1995               174      90
# Don't Let Me Down                 2016               160      87
# One Kiss (with Dua Lipa)          2018               124      86
# ...                                ...               ...     ...
# Memories                          2021                91      33
# 7 rings                           2019               140      32
# lovely (with Khalid)              2018               115      30
# All of Me                         2013               120      26
# when the party's over             2019                83      11
#
#                                   danceability  loudness.dB  liveness  \
# title
# Can't Hold Us - feat. Ray Dalton            64           -4         9
# ...

# %%
#avg of all the energy

# %%
df= pd.read_csv('modified.csv')
df.groupby(['length']).sum()
# Out:
#         year  beats.per.minute  energy  danceability  loudness.dB  liveness  \
# length
# 119     2017               134      39            87           -9        30
# 141     2021                91      72            70           -4        32
# 157     2019               136      62            88           -6        11
# 158     2018                90      48            76           -6         7
# 167     2018                75      61            74           -5        12
# ...      ...               ...     ...           ...          ...       ...
# 270     4028               235      87           128          -14        16
# 282     2014                79      45            78           -6        18
# 313     2018               155      73            83           -4        12
# 321     2014               171      74            69           -5        37
# 354     1975                71      40            41          -10        30
#
# ...

# %%
#context may.  not be relevant here but it summs

# %%
df= pd.read_csv('modified.csv')
df.groupby(['year']).count()
# Out:
#       title  artist  top genre  beats.per.minute  energy  danceability  \
# year
# 1975      1       1          1                 1       1             1
# 1995      1       1          1                 1       1             1
# 2004      1       1          1                 1       1             1
# 2008      1       1          1                 1       1             1
# 2012      3       3          3                 3       3             3
# 2013      4       4          4                 4       4             4
# 2014      6       6          6                 6       6             6
# 2015     13      13         13                13      13            13
# 2016     16      16         16                16      16            16
# 2017     12      12         12                12      12            12
# 2018     20      20         20                20      20            20
# 2019     16      16         16                16      16            16
# ...

# %%
df= pd.read_csv('modified.csv')
df['count']=1

df
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %%
df= pd.read_csv('modified.csv')
df['count']=1

df.groupby(['year']).count()['count']
# Out:
# year
# 1975     1
# 1995     1
# 2004     1
# 2008     1
# 2012     3
# 2013     4
# 2014     6
# 2015    13
# 2016    16
# 2017    12
# 2018    20
# 2019    16
# 2020     3
# 2021     3
# Name: count, dtype: int64

# %%
df= pd.read_csv('modified.csv')
df['count']=1

df.groupby(['year','top genre']).count()['count']
# Out:
# year  top genre
# 1975  classic rock              1
# 1995  beatlesque                1
# 2004  alternative rock          1
# 2008  acoustic pop              1
# 2012  modern rock               2
#                                ..
# 2020  dance pop                 1
#       north carolina hip hop    1
# 2021  cali rap                  1
#       pop                       1
#       pop dance                 1
# Name: count, Length: 62, dtype: int64

# %%
for df in pd.read_csv('modified.csv', chunksize=5):
    print("Chunk DF")
    print(df)
# Out:
# Chunk DF
#                     title         artist                  top genre  year  \
# 0         Blinding Lights     The Weeknd  canadian contemporary r&b  2020
# 1        Watermelon Sugar   Harry Styles                        pop  2019
# 2  Mood (feat. iann dior)       24kGoldn                   cali rap  2021
# 3       Someone You Loved  Lewis Capaldi                        pop  2019
# 4                 Perfect     Ed Sheeran                        pop  2017
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
# 1                95      82            55           -4        34       56
# 2                91      72            70           -4        32       73
# 3               110      41            50           -6        11       45
# 4                95      45            60           -6        11       17
#
#    length  acousticness  speechiness  popularity  total
# ...

# %%
new_df = pd.DataFrame(columns=df.columns)
for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['year']).count()

    new_df= pd.concat([new_df, results])

# %%
df
# Out:
#                                   title       artist         top genre  year  \
# 95                            One Dance        Drake  canadian hip hop  2016
# 96                                Sugar     Maroon 5               pop  2015
# 97                             Emotions   Mark Mendy         pop dance  2021
# 98                           Cold Water  Major Lazer         dance pop  2018
# 99  I Took A Pill In Ibiza - Seeb Remix  Mike Posner         dance pop  2016
#
#     beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 95               104      61            79           -6        32       43
# 96               120      79            75           -7         9       88
# 97               126      83            66           -5        40       74
# 98                93      80            61           -5        16       50
# 99               102      73            67           -7         9       66
#
# ...
